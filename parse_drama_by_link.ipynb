# %%
from selenium.webdriver import Chrome
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import joblib
import pandas as pd
import os

# %% [markdown]
# # 1. Скачиваем с официального сайта Selenium веб-драйвер удобного вам браузера и прописываем к нему путь.

# %%
driver = Chrome(executable_path='/Users/nikolaevaanna/WebDriver/bin/chromedriver')

# %% [markdown]
# # 2. Функция ниже вытаскивает нужный текст из tei-разметки реплики одного персонажа (пока исключаем комментарии к сценам, которые находятся внутри тега "tei-stage")

# %%
def get_speaker_and_text(speaker):
    
    # так получаем имя персонажа, если есть:
    name = speaker.find("tei-speaker").text.strip(".") if speaker.find("tei-speaker") else "" 
                
    # затем удаляем это имя, а также комментарии к сцене (когда кто-то заходит, выходит, чихает, улыбается и т.п.)
    _ = [name.decompose() for name in speaker("tei-speaker")]
    _ = [stage_note.decompose() for stage_note in speaker("tei-stage")]
        
    # потом вытаскиваем текст из всевозможных тегов (пока я выявила такие, но, может, еще есть)
    text = ""
    if speaker.find("tei-p", {"data-origname": "p"}):
        text += " ".join([i.text.strip() for i in speaker("tei-p", {"data-origname": "p"})])
    if speaker.find("tei-lg"):
        text += " ".join([i.text.strip() for i in speaker("tei-lg")])
    if speaker.find("tei-l"):
        text += " ".join([i.text.strip() for i in speaker("tei-l")])
        
    return (name, text) # возвращаем имя персонажа и реплику

# %% [markdown]
# # 3. Основная функция проходится по пьесе и собирает цепочки из реплик, которые выглядят примерно так:
#
# ```[('Ефимовна', 'Потолкай-ка, мать, старца! Словно, никак, богу душу отдает.'),
#  ('Назаровна', 'Божий человек, а божий человек! Жив ты, аль уж помер?'),
#  ('Савва',
#   'Зачем помер? Жив, матушка.  Укрой-ка мне,\n            убогонькая, ноги! Вот так. Правую больше. Вот так, матушка. Дай бог здоровья.'),
#  ('Назаровна', 'Спи, батюшка.'),
#  ('Савва',
#   'Какой уж тут сон? Было б терпенье муку эту перенесть, а спанья, матушка, хоть и не\n            надо. Не достоин грешник покой иметь. Это что шумит, богомолочка?'),
#   ```

# %% [markdown]
# В пьесах могут быть акты, действия, сцены, явления, например:
#     - пьеса в четырех действиях
#     - пьеса в трех актах (30 сцен)
#     - просто 1 сцена
#     и т.п.
# Вроде бы парсер разметки, который ниже, может распознавать все возможные паттерны и собирать цепочки сцен. Возможно, парсер работает с ошибками, которые я не отловила, но вроде бы основная структура пьес такая.

# %%
def parse_tei(link, driver):
    
    """
    Returns:
    * a list of drama contents (drama_chain) in the following format:

    drama_chain = [scenes]
    scenes = [[(speaker, text), ... ,(speaker, text)], 
              [(speaker, text), ... ,(speaker, text)], 
              ...]
    
    Arguments:
    
    * link - link to the drama page
    * driver - Selenium WebDriver    
    
    """
    
    tei_link = link + '#tei'
    
    driver.get(tei_link)
    WebDriverWait(driver, timeout=20).until(lambda d: d.find_element_by_tag_name("tei-sp"))
    
    soup = BeautifulSoup(driver.page_source, "lxml")
        
    drama_chain = []
    
    acts = soup.findAll("tei-div", {"type":"act"})
    
    if len(acts) != 0: 
        # если есть акты
        for act in acts:
            act_chain = []
            scenes = act.findAll("tei-div", {"type":"scene"})
            if len(scenes) != 0:
                # если есть сцены
                for scene in scenes:
                    speakers = scene("tei-sp")
                    scene_chain = []
                    for speaker in speakers:    
                        scene_chain.append(get_speaker_and_text(speaker))
                    drama_chain.append(scene_chain)

            else: 
                # если нет сцен
                speakers = act("tei-sp")
                for speaker in speakers:
                    act_chain.append(get_speaker_and_text(speaker))
                drama_chain.append(act_chain)   
                
    else: 
        # если нет актов
        scenes = soup.findAll("tei-div", {"type":"scene"})
        
        if len(scenes) != 0: 
            # если нет актов, но есть сцены
            for scene in scenes:
                speakers = scene.findAll("tei-sp")
            
                scene_chain = []
            
                for speaker in speakers:
                    scene_chain.append(get_speaker_and_text(speaker))
                
                drama_chain.append(scene_chain)
        else: 
            # если нет ни актов, ни сцен
            speakers = soup.findAll("tei-sp")
            chain = []
            for speaker in speakers:
                chain.append(get_speaker_and_text(speaker))
            drama_chain.append(chain)
    
    title = link.split("/")[-1]
    # сохраним каждую пьесу в pickle
    joblib.dump(drama_chain, "drama" + os.sep + title + ".pkl") 
    
    print(title + " successfully parsed!")
    
    # return drama_chain
    return drama_chain

# %%
driver.quit()

# %% [markdown]
# # Попробуем распарсить все ссылки

# %%
df = pd.read_csv("dracor-rus-list.csv")
df.head()
# Out:
#                             authors      title  \
# 0        Андреев, Леонид Николаевич  К звёздам
# 1        Андреев, Леонид Николаевич      Мысль
# 2        Андреев, Леонид Николаевич    Не убий
# 3  Афиногенов, Александр Николаевич   Машенька
# 4        Бабель, Исаак Эммануилович      Мария
#
#                                          link  written  premiered  printed  \
# 0   https://dracor.org/rus/andreyev-k-zvezdam   1905.0     1906.0      NaN
# 1        https://dracor.org/rus/andreyev-mysl   1913.0     1914.0   1914.0
# 2     https://dracor.org/rus/andreyev-ne-ubiy   1913.0     1913.0   1913.0
# 3  https://dracor.org/rus/afinogenov-mashenka   1940.0     1941.0   1941.0
# 4         https://dracor.org/rus/babel-marija   1934.0     1964.0   1935.0
#
#                                 source         id
# 0  Библиотека Максима Мошкова (lib.ru)  rus000194
# 1  Библиотека Максима Мошкова (lib.ru)  rus000137
# 2  Библиотека Максима Мошкова (lib.ru)  rus000138
# 3                           Wikisource  rus000167
# 4                Wikilivres/Bibliowiki  rus000119

# %%
links = list(df.link)
len(links)
# Out:
# 210

# %%
os.mkdir("drama")

# %%
for link in links:
    parse_tei(link=link,
              driver=driver)
# Out:
# andreyev-k-zvezdam successfully parsed!
# andreyev-mysl successfully parsed!
# andreyev-ne-ubiy successfully parsed!
# afinogenov-mashenka successfully parsed!
# babel-marija successfully parsed!
# babel-zakat successfully parsed!
# belsky-skazanie-o-nevidimom-grade-kitezhe successfully parsed!
# blok-balaganchik successfully parsed!
# blok-korol-na-ploschadi successfully parsed!
# blok-neznakomka successfully parsed!
# bulgakov-adam-i-eva successfully parsed!
# bulgakov-batum successfully parsed!
# bulgakov-beg successfully parsed!
# bulgakov-dni-turbinyh successfully parsed!
# bulgakov-ivan-vasilevich successfully parsed!
# bulgakov-kabala-svjatosh successfully parsed!
# bulgakov-poloumnyj-zhurden successfully parsed!
# bulgakov-poslednie-dni successfully parsed!
# bulgakov-vojna-i-mir successfully parsed!
# bulgakov-zojkina-kvartira successfully parsed!
# glinka-velzen successfully parsed!
# gogol-teatralnyi-razezd successfully parsed!
# gogol-tjazhba successfully parsed!
# gogol-utro-delovogo-cheloveka successfully parsed!
# gogol-zhenitba successfully parsed!
# gogol-igroki successfully parsed!
# gogol-lakeiskaja successfully parsed!
# gogol-otryvok successfully parsed!
# gogol-revizor successfully parsed!
# gorky-egor-bulychov-i-drugie successfully parsed!
# gorky-na-dne successfully parsed!
# gorky-vassa-zheleznova successfully parsed!
# griboyedov-gore-ot-uma successfully parsed!
# griboyedov-molodye-suprugi successfully parsed!
# gumilyov-gondla successfully parsed!
# gumilyov-akteon successfully parsed!
# gumilyov-ditja-allaha successfully parsed!
# gumilyov-don-zhuan-v-egipte successfully parsed!
# dashkova-toisiokov successfully parsed!
# zagoskin-blagorodnyj-teatr successfully parsed!
# kapnist-antigona successfully parsed!
# kapnist-yabeda successfully parsed!
# kedrin-rembrandt successfully parsed!
# knyazhnin-chudaki successfully parsed!
# knyazhnin-didona successfully parsed!
# knyazhnin-hvastun successfully parsed!
# knyazhnin-neudachnyj-primiritel successfully parsed!
# knyazhnin-olga successfully parsed!
# knyazhnin-rosslav successfully parsed!
# knyazhnin-traur successfully parsed!
# knyazhnin-vadim-novgorodskij successfully parsed!
# kokoshkin-vospitanie successfully parsed!
# kropotov-fomushka successfully parsed!
# krylov-amerikantsy successfully parsed!
# krylov-filomela successfully parsed!
# krylov-modnaja-lavka successfully parsed!
# krylov-pirog successfully parsed!
# krylov-podschipa-ili-trumf successfully parsed!
# krylov-prokazniki successfully parsed!
# krylov-sonnyj-poroshok successfully parsed!
# krylov-urok-dochkam successfully parsed!
# lazhechnikov-okopirovalsya successfully parsed!
# lensky-horosha-i-durna successfully parsed!
# lermontov-maskarad successfully parsed!
# lermontov-menschen-und-leidenschaften successfully parsed!
# lermontov-strannyj-chelovek successfully parsed!
# leskov-rastochitel successfully parsed!
# lomonosov-demofont successfully parsed!
# lomonosov-tamira-i-selim successfully parsed!
# majkov-agriopa successfully parsed!
# majkov-femist-i-ieronima successfully parsed!
# mamin-sibirjak-malenkaja-pravda successfully parsed!
# mamin-sibirjak-zolotopromyshlenniki successfully parsed!
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-19-b2f369cdf146> in <module>
#       1 for link in links:
#       2     parse_tei(link=link,
# ----> 3               driver=driver)
#
# <ipython-input-15-723750e7c8d8> in parse_tei(link, driver)
#      20
#      21     driver.get(tei_link)
# ---> 22     WebDriverWait(driver, timeout=5).until(lambda d: d.find_element_by_tag_name("tei-sp"))
#      23
#      24     soup = BeautifulSoup(driver.page_source, "lxml")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      78             if time.time() > end_time:
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#      82     def until_not(self, method, message=''):
#
# TimeoutException: Message:

# %%
for link in links[73:]:
    parse_tei(link=link,
              driver=driver)
# Out:
# mayakovsky-banja successfully parsed!
# mayakovsky-klop successfully parsed!
# mayakovsky-misteriya-buff successfully parsed!
# merezhkovsky-pavel-pervyj successfully parsed!
# naydyonov-deti-vanjushina successfully parsed!
# nekrasov-akter successfully parsed!
# nekrasov-junost-lomonosova successfully parsed!
# nekrasov-shila-v-meshke-ne-utaish successfully parsed!
# nekrasov-zabrakovannye successfully parsed!
# nikolev-samolyubivyj-stihotvorec successfully parsed!
# ozerov-dmitrij-donskoj successfully parsed!
# ostrovsky-neozhidannyj-sluchaj successfully parsed!
# ostrovsky-dmitrij-samozvanets-i-vasilij-shujskij successfully parsed!
# ostrovsky-nevolnicy successfully parsed!
# ostrovsky-dohodnoe-mesto successfully parsed!
# ostrovsky-poslednyaya-zhertva successfully parsed!
# ostrovsky-goryachee-serdce successfully parsed!
# ostrovsky-svoi-sobaki-gryzutsya-chuzhaya-ne-pristavaj successfully parsed!
# ostrovsky-pozdnyaya-lyubov successfully parsed!
# ostrovsky-trudovoj-hleb successfully parsed!
# ostrovsky-tyazhelye-dni successfully parsed!
# ostrovsky-greh-da-beda-na-kogo-ne-zhivet successfully parsed!
# ostrovsky-prazdnichnyj-son-do-obeda successfully parsed!
# ostrovsky-utro-molodogo-cheloveka successfully parsed!
# ostrovsky-groza successfully parsed!
# ostrovsky-v-chuzhom-piru-pohmelje successfully parsed!
# ostrovsky-puchina successfully parsed!
# ostrovsky-volki-i-ovtsy successfully parsed!
# ostrovsky-les successfully parsed!
# ostrovsky-vospitannica successfully parsed!
# ostrovsky-za-chem-pojdesh-to-i-najdesh successfully parsed!
# ostrovsky-na-bojkom-meste successfully parsed!
# ostrovsky-semejnaya-kartina successfully parsed!
# ostrovsky-bednaja-nevesta successfully parsed!
# ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty successfully parsed!
# ostrovsky-bednost-ne-porok successfully parsed!
# ostrovsky-shutniki successfully parsed!
# ostrovsky-ne-ot-mira-sego successfully parsed!
# ostrovsky-beshenye-dengi successfully parsed!
# ostrovsky-ne-soshlis-harakterami successfully parsed!
# ostrovsky-snegurochka successfully parsed!
# ostrovsky-staryj-drug-luchshe-novyh-dvuh successfully parsed!
# ostrovsky-bespridannitsa successfully parsed!
# ostrovsky-ne-tak-zhivi-kak-hochetsya successfully parsed!
# ostrovsky-bez-viny-vinovatye successfully parsed!
# ostrovsky-svoi-ljudi successfully parsed!
# ostrovsky-ne-v-svoi-sani-ne-sadis successfully parsed!
# ostrovsky-bogatye-nevesty successfully parsed!
# petrov-ostrov-mira successfully parsed!
# pisarev-lukavin successfully parsed!
# pisarev-naslednica successfully parsed!
# pisarev-poezdka-v-kronshtadt successfully parsed!
# pisemskij-gorkaja-sudbina successfully parsed!
# plavilshchikov-ermak-pokoritel-sibiri successfully parsed!
# plavilshchikov-sgovor-kutejkina successfully parsed!
# prutkov-blondy successfully parsed!
# prutkov-chereposlov-sirech-frenolog successfully parsed!
# prutkov-fantaziya successfully parsed!
# prutkov-oprometchivyj-turka successfully parsed!
# prutkov-spor-drevnih-grecheskih-filosofov successfully parsed!
# prutkov-srodstvo-mirovyh-sil successfully parsed!
# pushkin-boris-godunov successfully parsed!
# pushkin-kamenniy-gost successfully parsed!
# pushkin-mocart-i-saleri successfully parsed!
# pushkin-pir-vo-vremja-chumy successfully parsed!
# pushkin-rusalka successfully parsed!
# pushkin-skupoj-rytsar successfully parsed!
# pushkin-stseny-iz-rytsarskih-vremen successfully parsed!
# rostopchina-neludimka successfully parsed!
# saltykov-shchedrin-smert-pazuhina successfully parsed!
# sollogub-chinovnik successfully parsed!
# sudovshchikov-neslyhannoe-divo successfully parsed!
# sumarokov-pustaja-ssora successfully parsed!
# sumarokov-rogonosets-po-voobrazheniju successfully parsed!
# sumarokov-semira successfully parsed!
# sumarokov-sinav-i-truvor successfully parsed!
# sumarokov-ssora-u-muzha-s-zhenoj successfully parsed!
# sumarokov-tresotinius successfully parsed!
# sumarokov-artistona successfully parsed!
# sumarokov-vzdorschitsa successfully parsed!
# sumarokov-chudovischi successfully parsed!
# sumarokov-dimitrij-samozvanets successfully parsed!
# sumarokov-gamlet successfully parsed!
# sumarokov-horev successfully parsed!
# sumarokov-opekun successfully parsed!
# sumarokov-pridanoe-obmanom successfully parsed!
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-28-18e229307f24> in <module>
#       1 for link in links[73:]:
#       2     parse_tei(link=link,
# ----> 3               driver=driver)
#
# <ipython-input-24-dd8724974273> in parse_tei(link, driver)
#      20
#      21     driver.get(tei_link)
# ---> 22     WebDriverWait(driver, timeout=20).until(lambda d: d.find_element_by_tag_name("tei-sp"))
#      23
#      24     soup = BeautifulSoup(driver.page_source, "lxml")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      78             if time.time() > end_time:
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#      82     def until_not(self, method, message=''):
#
# TimeoutException: Message:

# %%
for link in links[159:]:
    parse_tei(link=link,
              driver=driver)
# Out:
# sukhovo-kobylin-delo successfully parsed!
# sukhovo-kobylin-smert-tarelkina successfully parsed!
# sukhovo-kobylin-svadba-krechinskogo successfully parsed!
# tolstoy-smert-ioanna-groznogo successfully parsed!
# tolstoy-tsar-boris successfully parsed!
# tolstoy-tsar-fedor-ioannovich successfully parsed!
# tolstoy-vlast-tmy successfully parsed!
# tolstoy-zhivoy-trup successfully parsed!
# tretyakov-protivogazy successfully parsed!
# turgenev-gde-tonko-tam-i-rvetsja successfully parsed!
# turgenev-holostjak successfully parsed!
# turgenev-mesjats-v-derevne successfully parsed!
# turgenev-nahlebnik successfully parsed!
# turgenev-neostorozhnost successfully parsed!
# turgenev-provintsialka successfully parsed!
# turgenev-razgovor-na-bolshoj-doroge successfully parsed!
# turgenev-vecher-v-sorrente successfully parsed!
# turgenev-zavtrak-u-predvoditelja successfully parsed!
# fonvizin-brigadir successfully parsed!
# fonvizin-korion successfully parsed!
# fonvizin-nedorosl successfully parsed!
# fonvizin-vybor-guvernera successfully parsed!
# kheraskov-osvobozhdennaja-moskva successfully parsed!
# kheraskov-plamena successfully parsed!
# kheraskov-venecianskaya-monahinya successfully parsed!
# khlebnikov-snezhimochka successfully parsed!
# khmelnitsky-vzaimnye-ispytaniya successfully parsed!
# khmelnitsky-govorun successfully parsed!
# khmelnitsky-svetskiy-sluchay successfully parsed!
# khmelnitsky-vozdushnye-zamki successfully parsed!
# chekhov-chaika successfully parsed!
# chekhov-djadja-vanja successfully parsed!
# chekhov-ivanov successfully parsed!
# chekhov-jubilej successfully parsed!
# chekhov-leshii successfully parsed!
# chekhov-medved successfully parsed!
# chekhov-na-bolshoi-doroge successfully parsed!
# chekhov-noch-pered-sudom successfully parsed!
# chekhov-predlozhenie successfully parsed!
# chekhov-svadba successfully parsed!
# chekhov-tatjana-repina successfully parsed!
# chekhov-tragik-ponevole successfully parsed!
# chekhov-tri-sestry successfully parsed!
# chekhov-vishnevyi-sad successfully parsed!
# shakhovskoy-urok-koketkam successfully parsed!
# shakhovskoy-ne-lubo-ne-slushai successfully parsed!
# shakhovskoy-pustodomy successfully parsed!
# shakhovskoy-svoya-semya successfully parsed!
# ekaterina-vtoraja-iz-zhizni-rjurika successfully parsed!
# ekaterina-vtoraja-o-vremja successfully parsed!
# ekaterina-vtoraja-rasstroennaja-semja successfully parsed!

# %%
files = ["drama" + os.sep + i for i in os.listdir("drama")]

# %%
for i in files:
    drama = joblib.load(i)
    for j in drama:
        for k in j:
            if k[1] == "" or None:
                print(i)
#    print(len(drama))
# Out:
# drama/gogol-revizor.pkl
# drama/gogol-revizor.pkl
# drama/bulgakov-poslednie-dni.pkl
# drama/bulgakov-poslednie-dni.pkl
# drama/bulgakov-poslednie-dni.pkl
# drama/bulgakov-poslednie-dni.pkl
# drama/lermontov-strannyj-chelovek.pkl
# drama/kokoshkin-vospitanie.pkl
# drama/tolstoy-zhivoy-trup.pkl
# drama/lermontov-menschen-und-leidenschaften.pkl
# drama/lermontov-menschen-und-leidenschaften.pkl
# drama/lermontov-menschen-und-leidenschaften.pkl
# drama/lermontov-menschen-und-leidenschaften.pkl
# drama/lermontov-menschen-und-leidenschaften.pkl
# drama/ostrovsky-groza.pkl
# drama/ostrovsky-groza.pkl
# drama/tretyakov-protivogazy.pkl
# drama/afinogenov-mashenka.pkl
# drama/knyazhnin-chudaki.pkl

# %%
# drama = joblib.load("drama/bulgakov-poslednie-dni.pkl") - тут ошибки в самой разметке - в цепочках 1 и 2. Вместо tei-p tei-stage
# drama = joblib.load("drama/kokoshkin-vospitanie.pkl") - тоже ошибка в разметке, в 18-й цепочке
# drama = joblib.load("drama/tolstoy-zhivoy-trup.pkl") - кривовато парсится пара первых строчек в 48 цепочке
# drama = joblib.load("drama/ostrovsky-groza.pkl") - c 25-й цепочки поехала разметка - неясно, кто говорит и т.п. Надо фиксить 
# drama = joblib.load("drama/afinogenov-mashenka.pkl") - сомнительная разметка в одном месте в цепочке 4
drama = joblib.load("drama/knyazhnin-chudaki.pkl") # в одном месте ошибка в парсинге - там не захватился текст tei-l 
len(drama)
# Out:
# 44

# %%
for i,j in enumerate(drama):
    for k in j:
        if k[1] == "" or None:
            print(i)
# Out:
# 32

# %%
drama[32]
# Out:
# [('Высонос',
#   'Я так сердит, что свет мне кажется, как ночь. Надеяся на то, что глупый этот струсит, Намерен я его на поединок звать... Ну, ежели его черт храбрости укусит И если вместо он того, чтобы дрожать, Приободрившися, не вздумает бежать?.. Пропал я!.. Но тому быть, кажется, не можно. Слыхал я: филозо́ф не любит умирать. Притом же поступил я очень осторожно: Бумаги десть на грудь взложил я вместо лат.'),
#  ('Пролаз', 'Зачем ты здесь один, любезный друг и брат?'),
#  ('Высонос',
#   'Один? любезный друг и брат! — о! он робеет! Коль чести правила бездельник разумеет...'),
#  ('Пролаз', 'Ну что ж?'),
#  ('Высонос',
#   'Ну, только... Черт его пускай возьмет! Он смотрит, будто бы меня совсем сожрет.'),
#  ('Пролаз',
#   'Его мне бледный вид добра не предвещает: Он, кажется, меня, как репку, искусает.'),
#  ('Высонос',
#   'Ну, милый Высонос! приободрись, дружок! Он храбрым кажется, быть может, только с рожи. Ты знаешь ли, на что твои дела похожи?'),
#  ('Пролаз', 'На что?'),
#  ('Высонос', 'На то, за что сажают вас в острог.'),
#  ('Пролаз',
#   'От ужаса ни рук не чувствую, ни ног, Однако должно скрыть мне робость ради чести.'),
#  ('Высонос',
#   'Изрядно! он дрожит! Что ж ты не говоришь? Не видя ничего, уж ты как лист дрожишь.'),
#  ('Пролаз',
#   'Не горячися так; сказать тебе без лести, От сердца я дрожу и бойся ты меня.'),
#  ('Высонос',
#   'Бояться мне? тебя!.. тебя? такого пня? Ты должен отвечать за смертную обиду, Котора сделана и барину и мне. Хоть тресни, но отсель дотоле я не выду, Доколе кортиком не прилеплю к стене.'),
#  ('Пролаз', 'Разбойник ты! ведь я, ты видишь, безоружен!'),
#  ('Высонос',
#   'Ты судишь по себе равно и обо мне: О чести знать тебя я более досужен. Для защищения тебе коль кортик нужен, Возьми, вот он, и знай: я честный человек.'),
#  ('Пролаз',
#   'Увидишь, я каков; твои кортик поднимаю; Но, как я филозо́ф, то ведай, что вовек Я первый брани, драк ни с кем не начинаю. Ты наступай.'),
#  ('Высонос', 'Нет, ты.'),
#  ('Пролаз', 'Ведь ты обижен был.'),
#  ('Высонос',
#   'Ты правду говоришь, я это позабыл. Давай! Постой! еще мы не уговорились, Колоться ль должно нам иль рубку произвесть'),
#  ('Пролаз', 'Что до меня, моя рубиться любит честь.'),
#  ('Высонос', 'Моя колоть.'),
#  ('Пролаз', 'Так мы еще не согласились?'),
#  ('Высонос', 'Не соглашуся я рубиться никогда.'),
#  ('Пролаз', 'А я колоть, — итак, дуэль не состоялся.'),
#  ('Высонос',
#   'Хоть трусом почитал тебя я завсегда, Не думал, чтоб Пролаз колоться отказался.'),
#  ('Пролаз', 'Кто колет, разве тот считается храбрей?'),
#  ('Высонос', 'Конечно.'),
#  ('Пролаз',
#   'Ин изволь, и стань же в позитуру. Увидишь, проколю как я твою фигуру! Да отчего, скажи, ты кажешься толстей? За час ты тоне был.'),
#  ('Высонос',
#   'Трус только лишь худеет, А храбрый человек час от часу толстеет.'),
#  ('Пролаз',
#   'Да что та храбрость вся застегнута твоя? А пред тобою — на! — открыта вся моя.'),
#  ('Высонос', 'Коль хочешь, ты себе, пожалуй, застегнися.'),
#  ('Пролаз', 'Послушай!.. Человек ты честный, говоришь?'),
#  ('Высонос', 'И очень.'),
#  ('Пролаз', 'Если так, ощупать мне велишь Ты прежде честь твою.'),
#  ('Высонос',
#   'Нет, нет, ты тем не льстися, Она и без того, дружок! видна, как скло.'),
#  ('Пролаз',
#   'Однако ж твой кафтан не так ведь, как стекло. Не видно, под него какую вещь заправил. Знать надо, из чего ты честь твою составил, Котору грубо так ты скрыл под твой кафтан. Честь оттопырилась твоя, мне очень видно.'),
#  ('Высонос', 'Так думать обо мне или тебе не стыдно?'),
#  ('Пролаз',
#   'Послушай: я, узнав преподлый твой обман, Когда начну колоть, то метить в рожу стану. Изрежу, проколю твое лицо насквозь.'),
#  ('Высонос',
#   'Бездельник сделает мою красу хоть брось. Уверить чем тебя, что нет во мне обману? Божиться ль?'),
#  ('Пролаз',
#   'Не божись, а лучше договор Мы сделаем с тобой. Чтобы окончить спор, Положим кортики мы прежде на пол оба, Чтобы с оружием осталась наша злоба; Потом, по-дружески сошедшись, разберем; И если честь твоя толста не от обмана, Опять, коль хочешь ты, мы кортики возьмем.'),
#  ('Высонос', 'Изволь, кладу тебе толь страшного тирана.'),
#  ('Пролаз', 'И я. Вот я уже шагнул.'),
#  ('Высонос', ''),
#  ('<Вместе>', 'Раз, два, три.'),
#  ('Высонос', 'Лишний шаг ты, плут, с меня слупил.'),
#  ('Пролаз',
#   'Изволь, я раз еще ступлю в твою угоду. Бездельник! храбрость вся рассыпалась твоя! Мошенник!'),
#  ('Высонос', 'Не спущу такому я уроду!'),
#  ('Пролаз', 'К ружью! к ружью!'),
#  ('Высонос', 'К ружью! взбешен теперь-то я!'),
#  ('Пролаз',
#   'Кровопролитие у нас пойдет ужасно. Кто так сердит, как я, что может быть опасно! Бездельник! будь готов себя оборонять.'),
#  ('Высонос', 'Прощайся с светом!'),
#  ('Пролаз', 'Нас никто нейдет разнять.'),
#  ('Высонос',
#   'Как люди нонече немилосерды стали! Мы кровь лием, а к нам не выглянет никто!.. Я стану-ка шуметь, авось поможет то.'),
#  ('Оба вместе', 'Ге! ге! ге!'),
#  ('Пролаз',
#   'Никого. Как будто все пропали. Вот люди каковы: пожалуй, ты умри, — Никто из них тебе не скажет добра слова.'),
#  ('Высонос',
#   'Пролаз! по совести, что ты ни говори, А чтобы умереть, в том много есть пустого.'),
#  ('Пролаз',
#   'Ты правду говоришь... Что ж нам — начать ли снова Тот бой, который мы так храбро провели? Противу чести мы не сделали прорухи.'),
#  ('Высонос',
#   'Довольно, кажется, мы крови пролили, И помнится, у нас по полной оплеухе.'),
#  ('Пролаз',
#   'Мы равной храбрости и одинаких сил, И если б, Высонос, день целый мы дралися, Из нас никто б один другого не убил.'),
#  ('Высонос',
#   'А как у нас теперь и раны завелися, То мы скорее их пойдем перевязать.'),
#  ('Пролаз',
#   'Не лучше ль в доме нам питейном побывать? От храбрости всегда ужасна жажда мучит.'),
#  ('Высонос',
#   'То правда, у меня от ней и брюхо пучит. Привычка храбрецов приятна очень мне, Подравшись, утопить свою вражду в вине.')]
